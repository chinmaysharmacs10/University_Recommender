# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('admission_data_cleaned.csv')

# %%
df.head()
# Out:
#    researchExp  industryExp  toeflScore  internExp   greV   greQ  greA  \
# 0            0           24       113.0        2.0  159.0  170.0   4.0
# 1            0            0       102.0        0.0  150.0  167.0   3.0
# 2           12           24       111.0        4.0  158.0  170.0   4.5
# 3            0            0       111.0        1.0  152.0  161.0   4.0
# 4            0           27       105.0        0.0  154.0  165.0   3.5
#
#       ugCollege                                           univName  cgpa_4
# 0    IIT Indore  Virginia Polytechnic Institute and State Unive...   3.080
# 1          COEP  Virginia Polytechnic Institute and State Unive...   3.212
# 2  NIT Rourkela  Virginia Polytechnic Institute and State Unive...   3.648
# 3           SRM  Virginia Polytechnic Institute and State Unive...   3.640
# 4  NIT-warangal  Virginia Polytechnic Institute and State Unive...   2.804

# %% [markdown]
# # Undergraduate Colleges data

# %%
# Number of different Undergraduate colleges
df['ugCollege'].nunique()
# Out:
# 980

# %%
df['ugCollege'].value_counts()
# Out:
# VTU                                                      703
# MU                                                       673
# Anna University                                          406
# Pune University                                          275
# JNTU                                                     258
#                                                         ...
# S.S.P.M college of Engineering-mumbai university           1
# The Bengal Engineering And Science University Shibpur      1
# Canara Engineering College                                 1
# University of Calcutta                                     1
# Federal University of Itajuba (Brazil)                     1
# Name: ugCollege, Length: 980, dtype: int64

# %% [markdown]
# # Since there are 980 different UG Colleges, they will add alot of dimensions to the data after one-hot encoding. So, they are not considered as a feature.

# %%
# remove ugCollege from dataset
df = df.drop('ugCollege',axis=1)

# %%
################################################################################################################################

# %% [markdown]
# # Number of admits per University

# %%
# Number of universities (classes)
df['univName'].nunique()
# Out:
# 36

# %%
# Number of entries in each class
entries = df['univName'].value_counts()
fig_dims = (8, 8)
fig, ax = plt.subplots(figsize=fig_dims)
sns.barplot(x=entries,y=entries.index, ax=ax)

# %% [markdown]
# # From the plot, we observe that the dataset is imbalanced

# %%
################################################################################################################################

# %% [markdown]
# # Average of parameters for each university

# %%
avg_per_university = df.groupby('univName', as_index=False)['greQ','greV','greA','cgpa_4','toeflScore','researchExp','industryExp','internExp'].mean()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.

# %%
avg_per_university
# Out:
#                                              univName        greQ        greV  \
# 0                            Arizona State University  163.384686  152.344096
# 1                          Carnegie Mellon University  164.400560  156.212885
# 2                                  Clemson University  162.467033  152.901099
# 3                                  Cornell University  163.742268  154.494845
# 4                             George Mason University  160.040323  149.177419
# 5                     Georgia Institute of Technology  165.716981  157.797170
# 6                  New Jersey Institute of Technology  157.912821  147.276923
# 7                                 New York University  163.586538  154.403846
# 8                     North Carolina State University  165.411852  155.035556
# 9                             Northeastern University  160.845468  150.878158
# 10                     Ohio State University Columbus  165.301370  155.972603
# 11                                  Purdue University  164.923077  155.569231
# 12        Rutgers University New Brunswick/Piscataway  164.860000  153.720000
# 13                                       SUNY Buffalo  162.679115  153.325035
# 14                                   SUNY Stony Brook  164.381107  153.615635
# 15                                Syracuse University  160.828715  151.450882
# 16           Texas A and M University College Station  164.856734  155.154728
# 17                              University of Arizona  162.050980  153.827451
# 18                    University of California Irvine  164.232558  154.627907
# 19                           University of Cincinnati  162.541667  153.705357
# 20                     University of Colorado Boulder  163.911765  154.247059
# 21                              University of Florida  163.365801  153.692641
# 22                     University of Illinois Chicago  161.639669  152.148760
# 23            University of Illinois Urbana-Champaign  164.578431  155.676471
# 24                University of Maryland College Park  162.048507  153.052239
# 25                University of Massachusetts Amherst  163.605505  153.642202
# 26                University of Minnesota Twin Cities  165.338798  154.415301
# 27             University of North Carolina Charlotte  160.730864  149.706173
# 28                         University of Pennsylvania  165.147059  155.970588
# 29                  University of Southern California  163.270440  152.886792
# 30                      University of Texas Arlington  158.871287  148.027228
# 31                         University of Texas Dallas  160.741639  150.151338
# 32                                 University of Utah  163.210843  153.283133
# 33                           University of Washington  162.948718  155.940171
# 34                    University of Wisconsin Madison  165.482456  156.131579
# 35  Virginia Polytechnic Institute and State Unive...  165.507143  156.392857
#
#         greA    cgpa_4  toeflScore  researchExp  industryExp  internExp
# 0   3.543819  3.177413  104.794280     0.797048     6.448339   0.671587
# 1   3.893557  3.145430  110.142857     0.848739     5.722689   0.602241
# 2   3.598901  2.988189  105.626374     0.692308     6.829670   0.703297
# 3   3.804124  3.383207  108.783505     0.268041     4.154639   0.948454
# 4   3.342742  2.716762  101.000000     0.330645     4.556452   0.153226
# 5   4.007075  3.254528  111.500000     0.698113     3.773585   0.905660
# 6   3.240000  2.705179   97.056410     0.456410     7.000000   0.682051
# 7   3.625000  3.169178  107.115385     0.788462     8.721154   1.096154
# 8   3.729630  3.210429  107.973333     0.577778     6.564444   0.850370
# 9   3.457652  3.186648  103.297177     0.185736     7.707281   0.710253
# 10  3.845890  3.246274  108.910959     0.890411     3.671233   0.650685
# 11  3.876923  3.407405  108.992308     0.492308     5.092308   0.800000
# 12  3.695000  3.055878  107.350000     0.800000     5.210000   1.950000
# 13  3.604703  3.034632  105.716459     0.323651     6.954357   0.650069
# 14  3.633550  3.303615  106.684039     0.872964     8.990228   0.928339
# 15  3.511335  2.983034  104.118388     0.231738     5.498741   0.488665
# 16  3.726361  3.286305  108.031519     0.590258     6.303725   0.810888
# 17  3.656863  2.954110  106.835294     0.082353     6.015686   0.294118
# 18  3.705426  3.203387  108.503876     0.806202     5.852713   0.945736
# 19  3.627976  3.107047  106.083333     0.622024     8.273810   0.660714
# 20  3.794118  3.377311  107.405882     0.547059     3.676471   0.858824
# 21  3.638095  3.197898  105.932900     0.595238     6.153680   0.796537
# 22  3.538529  3.196764  104.289256     0.330579     7.651240   0.634711
# 23  3.784314  3.388865  109.166667     0.901961     3.931373   1.294118
# 24  3.619440  2.904215  107.272388     0.347015     8.716418   0.712687
# 25  3.655963  3.380910  106.706422     0.660550     8.275229   0.990826
# 26  3.737705  3.422175  107.546448     0.726776     4.349727   0.732240
# 27  3.395062  2.984714  100.829630     0.328395     7.125926   0.688889
# 28  4.024510  3.446876  110.558824     0.303922     3.303922   0.470588
# 29  3.650943  3.333820  106.227987     0.537736     4.518868   0.874214
# 30  3.289975  2.842588   98.396040     0.163366     5.561881   0.551980
# 31  3.409239  3.067203  101.578595     0.336120     6.679766   0.484950
# 32  3.617470  3.121607  105.885542     0.801205     7.295181   0.843373
# 33  3.940171  3.014604  109.376068     1.461538     7.324786   1.017094
# 34  3.907895  3.521762  109.236842     0.543860     4.456140   0.789474
# 35  3.817857  3.335914  109.328571     1.592857     6.235714   1.242857

# %%
parameters = avg_per_university[['greQ','greV','greA','cgpa_4','toeflScore','researchExp','industryExp','internExp']]
for i in parameters.columns:
    fig_dims = (8, 8)
    fig, ax = plt.subplots(figsize=fig_dims)
    print("Variation of %s vs University" %(i))
    chart = sns.barplot(x=parameters[i],y=avg_per_university['univName'], ax=ax)
    plt.show()
# Out:
# Variation of greQ vs University
# Variation of greV vs University
# Variation of greA vs University
# Variation of cgpa_4 vs University
# Variation of toeflScore vs University
# Variation of researchExp vs University
# Variation of industryExp vs University
# Variation of internExp vs University

# %% [markdown]
# # ResearchExp, IndustryExp & InternExp have alot of variation, so the data needs to be scaled

# %%
################################################################################################################################

# %%
# Remove all the wrongly entered cgpa, cgpa should be <= 4.0
df = df[df['cgpa_4']<=4]

# %% [markdown]
# # Visualization of parameters

# %% [markdown]
# # Histogram to see the distribution

# %%
df.greV.hist()

# %%
df.greQ.hist()

# %%
df.greA.hist()

# %%
df.cgpa_4.hist()

# %%
df.toeflScore.hist()

# %% [markdown]
# # These parameters have a normal distribution

# %%
################################################################################################################################

# %% [markdown]
# # Boxplots to check for outliers

# %%
df.boxplot(column=['greQ'])

# %%
df.boxplot(column=['greV'])

# %%
df.boxplot(column=['greA'])

# %%
df.boxplot(column=['cgpa_4'])

# %%
df.boxplot(column=['toeflScore'])

# %%
df.boxplot(column=['researchExp'])

# %%
df.boxplot(column=['industryExp'])

# %%
df.boxplot(column=['internExp'])

# %% [markdown]
# # There are few outliers in greQ, greV, greA, cgpa_4 & toeflScore

# %% [markdown]
# # ResearchExp, IndustryExp & InternExp have random distribution

# %%
################################################################################################################################

# %%
df
# Out:
#        researchExp  industryExp  toeflScore  internExp   greV   greQ  greA  \
# 0                0           24       113.0        2.0  159.0  170.0   4.0
# 1                0            0       102.0        0.0  150.0  167.0   3.0
# 2               12           24       111.0        4.0  158.0  170.0   4.5
# 3                0            0       111.0        1.0  152.0  161.0   4.0
# 4                0           27       105.0        0.0  154.0  165.0   3.5
# ...            ...          ...         ...        ...    ...    ...   ...
# 11749            0            0        92.0        0.0  145.0  161.0   3.0
# 11750            0            0       106.0        0.0  151.0  159.0   3.5
# 11751            0            0        96.0        0.0  151.0  158.0   3.0
# 11752            0            0       113.0        0.0  159.0  163.0   3.5
# 11753            0            0        96.0        0.0  150.0  160.0   4.0
#
#                                                 univName    cgpa_4
# 0      Virginia Polytechnic Institute and State Unive...  3.080000
# 1      Virginia Polytechnic Institute and State Unive...  3.212000
# 2      Virginia Polytechnic Institute and State Unive...  3.648000
# 3      Virginia Polytechnic Institute and State Unive...  3.640000
# 4      Virginia Polytechnic Institute and State Unive...  2.804000
# ...                                                  ...       ...
# 11749                           Arizona State University  2.989474
# 11750                           Arizona State University  3.489600
# 11751                           Arizona State University  3.115789
# 11752                           Arizona State University  3.280000
# 11753                           Arizona State University  3.031579
#
# [11734 rows x 9 columns]

# %%
df.describe()
# Out:
#         researchExp   industryExp    toeflScore     internExp          greV  \
# count  11734.000000  11734.000000  11734.000000  11734.000000  11734.000000
# mean       0.521817      6.402165    105.317539      0.715016    152.790097
# std        3.185130     14.478641      7.520210      2.928754      5.463499
# min        0.000000      0.000000     65.000000      0.000000    134.000000
# 25%        0.000000      0.000000    101.000000      0.000000    149.000000
# 50%        0.000000      0.000000    106.000000      0.000000    153.000000
# 75%        0.000000      0.000000    111.000000      0.000000    156.750000
# max       53.000000    132.000000    120.000000     96.000000    170.000000
#
#                greQ          greA        cgpa_4
# count  11734.000000  11734.000000  11734.000000
# mean     162.711522      3.599857      3.088968
# std        4.287230      0.541725      0.650407
# min      140.000000      1.500000      0.000000
# 25%      160.000000      3.000000      2.933053
# 50%      163.000000      3.500000      3.200000
# 75%      166.000000      4.000000      3.436000
# max      170.000000      6.000000      4.000000

# %% [markdown]
# # Save the dataset for the classification model

# %%
df.to_csv('model_data.csv',index=False)
